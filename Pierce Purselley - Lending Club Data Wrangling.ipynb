# %% [markdown]
# # Pierce Purselley: Lending Club Data Exploration

# %% [markdown]
# # Lending Club Stats 2019 Q1

# %%
#import libraries to play with the data

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as st

# %%
#plots using seaborn
#sns.set()

#display plots in-line
#%matplotlib inline

#dataset
lendingclub_df = pd.read_csv('data/LoanStats3a.csv',low_memory=False,skiprows=1)
#dataset size
print('ROWS ' + str(lendingclub_df.shape) + ' COLUMNS')
# Out:
# ROWS (42538, 144) COLUMNS

# %%
lendingclub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42538 entries, 0 to 42537
# Columns: 144 entries, id to settlement_term
# dtypes: float64(115), object(29)
# memory usage: 46.7+ MB

# %%
lendingclub_df.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN     5000.0       5000.0           4975.0   36 months
# 1  NaN        NaN     2500.0       2500.0           2500.0   60 months
# 2  NaN        NaN     2400.0       2400.0           2400.0   36 months
# 3  NaN        NaN    10000.0      10000.0          10000.0   36 months
# 4  NaN        NaN     3000.0       3000.0           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ...  \
# 0   10.65%       162.87     B        B2  ...
# 1   15.27%        59.83     C        C4  ...
# 2   15.96%        84.33     C        C5  ...
# 3   13.49%       339.31     C        C1  ...
# 4   12.69%        67.79     B        B5  ...
#
#   orig_projected_additional_accrued_interest hardship_payoff_balance_amount  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# ...

# %%
lendingclub_df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term'],
#       dtype='object', length=144)

# %%
# Removing columns(axis=1) that have 'all' missing values
loan_data = lendingclub_df.dropna(how='all',axis=1)
#loan_data.dropna(axis=1,how='all')
print('ROWS ' + str(loan_data.shape) + ' COLUMNS')
# Out:
# ROWS (42538, 63) COLUMNS

# %%
loan_data.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt',
# ...

# %%
loan_data.head()
# Out:
#     id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0  NaN     5000.0       5000.0           4975.0   36 months   10.65%
# 1  NaN     2500.0       2500.0           2500.0   60 months   15.27%
# 2  NaN     2400.0       2400.0           2400.0   36 months   15.96%
# 3  NaN    10000.0      10000.0          10000.0   36 months   13.49%
# 4  NaN     3000.0       3000.0           3000.0   60 months   12.69%
#
#    installment grade sub_grade                 emp_title  ...  \
# 0       162.87     B        B2                       NaN  ...
# 1        59.83     C        C4                     Ryder  ...
# 2        84.33     C        C5                       NaN  ...
# 3       339.31     C        C1       AIR RESOURCES BOARD  ...
# 4        67.79     B        B5  University Medical Group  ...
#
#   pub_rec_bankruptcies tax_liens  hardship_flag debt_settlement_flag  \
# 0                  0.0       0.0              N                    N
# ...

# %%
loan_data.tail()
# Out:
#                                                     id  loan_amnt  \
# 42533                                              NaN     2525.0
# 42534                                              NaN     6500.0
# 42535                                              NaN     5000.0
# 42536  Total amount funded in policy code 1: 460296150        NaN
# 42537          Total amount funded in policy code 2: 0        NaN
#
#        funded_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 42533       2525.0            225.0   36 months    9.33%        80.69     B
# 42534       6500.0              0.0   36 months    8.38%       204.84     A
# 42535       5000.0              0.0   36 months    7.75%       156.11     A
# 42536          NaN              NaN         NaN      NaN          NaN   NaN
# 42537          NaN              NaN         NaN      NaN          NaN   NaN
#
#       sub_grade  emp_title  ... pub_rec_bankruptcies tax_liens  hardship_flag  \
# ...

# %%
#loan_data = loan_data.drop([115675,115676], axis=0)
# drop last n rows
p = loan_data[:-2]
p.tail()
#loan_data.drop(loan_data.tail(2).index,inplace=True)
# Out:
#         id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 42531  NaN     3500.0       3500.0            225.0   36 months   10.28%
# 42532  NaN     1000.0       1000.0              0.0   36 months    9.64%
# 42533  NaN     2525.0       2525.0            225.0   36 months    9.33%
# 42534  NaN     6500.0       6500.0              0.0   36 months    8.38%
# 42535  NaN     5000.0       5000.0              0.0   36 months    7.75%
#
#        installment grade sub_grade                   emp_title  ...  \
# 42531       113.39     C        C1                         NaN  ...
# 42532        32.11     B        B4  Halping hands company inc.  ...
# 42533        80.69     B        B3                         NaN  ...
# 42534       204.84     A        A5                         NaN  ...
# 42535       156.11     A        A3                   Homemaker  ...
#
#       pub_rec_bankruptcies tax_liens  hardship_flag debt_settlement_flag  \
# ...

# %%
p.describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv   installment  \
# count  42535.000000  42535.000000     42535.000000  42535.000000
# mean   11089.722581  10821.585753     10139.938785    322.623063
# std     7410.938391   7146.914675      7131.598014    208.927216
# min      500.000000    500.000000         0.000000     15.670000
# 25%     5200.000000   5000.000000      4950.000000    165.520000
# 50%     9700.000000   9600.000000      8500.000000    277.690000
# 75%    15000.000000  15000.000000     14000.000000    428.180000
# max    35000.000000  35000.000000     35000.000000   1305.190000
#
#          annual_inc           dti   delinq_2yrs  inq_last_6mths  \
# count  4.253100e+04  42535.000000  42506.000000    42506.000000
# mean   6.913656e+04     13.373043      0.152449        1.081424
# std    6.409635e+04      6.726315      0.512406        1.527455
# min    1.896000e+03      0.000000      0.000000        0.000000
# ...

# %%
# should I fill in settlement_amount, settlement_percentage, and settlement_term that are not in? (check count)  
# should that be a binary column?

# %%
# annual_inc?

# %%
# other columns that seem interesting: mths_since_last_delinq, mths_since_last_record

# %%
# plus checking the columns that I can't see?
# 'open_acc','pub_rec', 'revol_bal', 'revol_util', 'total_acc','initial_list_status', 
# 'out_prncp', 'out_prncp_inv', 'total_pymnt',  'total_pymnt_inv', 'total_rec_prncp', 
# 'total_rec_int','total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
# 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d'

# %%
p['id'].nunique()
# Out:
# 1

# %%
p = p.drop(columns='id')
p.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0     5000.0       5000.0           4975.0   36 months   10.65%       162.87
# 1     2500.0       2500.0           2500.0   60 months   15.27%        59.83
# 2     2400.0       2400.0           2400.0   36 months   15.96%        84.33
# 3    10000.0      10000.0          10000.0   36 months   13.49%       339.31
# 4     3000.0       3000.0           3000.0   60 months   12.69%        67.79
#
#   grade sub_grade                 emp_title emp_length  ...  \
# 0     B        B2                       NaN  10+ years  ...
# 1     C        C4                     Ryder   < 1 year  ...
# 2     C        C5                       NaN  10+ years  ...
# 3     C        C1       AIR RESOURCES BOARD  10+ years  ...
# 4     B        B5  University Medical Group     1 year  ...
#
#   pub_rec_bankruptcies  tax_liens hardship_flag debt_settlement_flag  \
# ...

# %%
# should I check in about which columsn have NaN, 0, or N?
# again, need to see the other columns
print('ROWS ' + str(loan_data.shape) + ' COLUMNS')
# put more information that you need here.
#print()
